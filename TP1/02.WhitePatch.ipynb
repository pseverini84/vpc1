# %% [markdown]
# # Operadores de píxel
#
# Brillo
# Contraste
# Gamma

# %%
#Si queremos que las imágenes sean mostradas en una ventana emergente quitar el inline
# %matplotlib inline

# OpenCV-Python utiliza NumPy para el manejo de imágenes
import numpy as np
# cv2 es el módulo python para acceder a OpenCV 
import cv2 as cv
# Usamos las poderosas herramientas de graficación de matplotlib para mostrar imágenes, perfiles, histogramas, etc
import matplotlib.pyplot as plt

# %%
img = cv.imread('WP_B.png')
imgRGB = cv.cvtColor(img, cv.COLOR_BGR2RGB)

img_mod=imgRGB.copy()

maxR=np.max(imgRGB[:,:,0])
maxG=np.max(imgRGB[:,:,1])
maxB=np.max(imgRGB[:,:,2])
#maxR=np.mean(imgRGB[:,:,0])*0.9
#maxG=np.mean(imgRGB[:,:,1])*0.9
#maxB=np.mean(imgRGB[:,:,2])*0.9

img_mod[:,:,0]=(255/maxR)*imgRGB[:,:,0]
img_mod[:,:,1]=(255/maxG)*imgRGB[:,:,1]
img_mod[:,:,2]=(255/maxB)*imgRGB[:,:,2]

img_mod=img_mod.round()
np.clip(img_mod, 0, 255, out=img_mod)   # Clip trunca a lo que se le diga (0 a 255)
img_mod=img_mod.astype('uint8') # Hay que castear a 8 bits
ax3=plt.subplot(221)
ax3.imshow(img_mod, cmap='gray', vmin=0, vmax=255)

ax3=plt.subplot(222)
ax3.imshow(imgRGB, cmap='gray', vmin=0, vmax=255)


img = cv.imread('WP_O.png')
imgRGB = cv.cvtColor(img, cv.COLOR_BGR2RGB)

img_mod=imgRGB.copy()

maxR=np.max(imgRGB[:,:,0])
maxG=np.max(imgRGB[:,:,1])
maxB=np.max(imgRGB[:,:,2])

img_mod[:,:,0]=(255/maxR)*imgRGB[:,:,0]
img_mod[:,:,1]=(255/maxG)*imgRGB[:,:,1]
img_mod[:,:,2]=(255/maxB)*imgRGB[:,:,2]

img_mod=img_mod.round()
np.clip(img_mod, 0, 255, out=img_mod)   # Clip trunca a lo que se le diga (0 a 255)
img_mod=img_mod.astype('uint8') # Hay que castear a 8 bits
ax3=plt.subplot(323)
ax3.imshow(img_mod, cmap='gray', vmin=0, vmax=255)

ax3=plt.subplot(224)
ax3.imshow(imgRGB, cmap='gray', vmin=0, vmax=255)
